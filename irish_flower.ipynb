# %%
from sklearn.datasets import load_iris  
from sklearn.model_selection import train_test_split  
from sklearn.neighbors import KNeighborsClassifier  
import numpy as np

# %%
knn = KNeighborsClassifier(n_neighbors=10,metric='minkowski')  # komsu sayisini artirdim minkowski formulunu kullandım
iris_veri_seti= load_iris()

# %%
ozellikler_egitim, ozellikler_test, hedef_egitim, hedef_test = train_test_split(iris_veri_seti['data'], iris_veri_seti['target'],random_state=0)

# %%
# Normal veri 
ozellikler_egitim
# Out:
# array([[5.9, 3. , 4.2, 1.5],
#        [5.8, 2.6, 4. , 1.2],
#        [6.8, 3. , 5.5, 2.1],
#        [4.7, 3.2, 1.3, 0.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [5. , 3.5, 1.6, 0.6],
#        [5.4, 3.7, 1.5, 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [6.5, 3. , 5.5, 1.8],
#        [6.7, 3.3, 5.7, 2.5],
#        [6. , 2.2, 5. , 1.5],
#        [6.7, 2.5, 5.8, 1.8],
#        [5.6, 2.5, 3.9, 1.1],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [5.5, 2.4, 3.8, 1.1],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.3, 2.8, 5.1, 1.5],
#        [4.9, 2.5, 4.5, 1.7],
#        [6.3, 2.5, 5. , 1.9],
#        [7. , 3.2, 4.7, 1.4],
#        [6.5, 3. , 5.2, 2. ],
#        [6. , 3.4, 4.5, 1.6],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.6, 2.9, 3.6, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [6.1, 3. , 4.6, 1.4],
#        [7.2, 3.2, 6. , 1.8],
#        [5.3, 3.7, 1.5, 0.2],
#        [4.3, 3. , 1.1, 0.1],
# ...

# %%
# Veriyi olceklendir
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
ozellikler_egitim = scaler.fit_transform(ozellikler_egitim)
ozellikler_test = scaler.transform(ozellikler_test)
ozellikler_egitim
# Out:
# array([[ 1.54399532e-02, -1.19254753e-01,  2.25126850e-01,
#          3.55797625e-01],
#        [-9.98450310e-02, -1.04039491e+00,  1.13559562e-01,
#         -2.98410911e-02],
#        [ 1.05300481e+00, -1.19254753e-01,  9.50314227e-01,
#          1.12707506e+00],
#        [-1.36797986e+00,  3.41315328e-01, -1.39259884e+00,
#         -1.31530348e+00],
#        [ 1.16828980e+00,  1.11030287e-01,  7.27179649e-01,
#          1.38416753e+00],
#        [-1.02212490e+00,  1.03217045e+00, -1.22524790e+00,
#         -8.01118523e-01],
#        [-5.60984968e-01,  1.49274053e+00, -1.28103155e+00,
#         -1.31530348e+00],
#        [-1.02212490e+00, -2.42210516e+00, -1.65358660e-01,
#         -2.86933568e-01],
#        [ 7.07149859e-01, -1.19254753e-01,  9.50314227e-01,
#          7.41436341e-01],
#        [ 9.37719827e-01,  5.71600368e-01,  1.06188152e+00,
#          1.64126001e+00],
#        [ 1.30724937e-01, -1.96153508e+00,  6.71396005e-01,
#          3.55797625e-01],
# ...

# %%
# Modeli eğitiyoruz
knn.fit(ozellikler_egitim, hedef_egitim)

yeni_veri_noktasi = [[3.5, 2.1, 3.4, 1.2]]
tahmin = knn.predict(yeni_veri_noktasi)

print(tahmin)
# Out:
# [2]

# %%
# Error
dogruluk = np.mean(knn.predict(ozellikler_test) == hedef_test) * 100

print("Doğruluk:", dogruluk)
# Out:
# Doğruluk: 97.36842105263158
